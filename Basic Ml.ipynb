# %% [markdown]
#                              LINEAR_REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\mmoni\OneDrive\Documents\DAY_5.xlsx')

# %%
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color='red',marker='+')
plt.title("Home_PRICE")
plt.xlabel("area")
plt.ylabel("price")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[72000]])
# Out:
# C:\Users\mmoni\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9957328.76712329])

# %%
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
plt.title("Home_PRICE")
plt.xlabel("area")
plt.ylabel("price")
plt.show()

# %% [markdown]
#                                       LOGISTIC_REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
db = pd.read_excel(r'C:\Users\mmoni\OneDrive\Documents\DAY_5_2.xlsx')
print(db)
# Out:
#    age  yn
# 0   23   0
# 1   22   1
# 2   21   0
# 3   20   1
# 4   19   1
# 5   18   0
# 6   17   1
# 7   16   1
# 8   15   0
# 9   14   1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(db[['age']],db. yn ,test_size=0.2)

# %%
x_train
# Out:
#    age
# 5   18
# 6   17
# 4   19
# 9   14
# 3   20
# 2   21
# 0   23
# 8   15

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[14]])
# Out:
# C:\Users\mmoni\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
plt.scatter(db.age,db.yn,color='red',marker='+')
plt.title("loan_pred")
plt.xlabel("age")
plt.ylabel("yn")
plt.show()

# %% [markdown]
# DECISION TREE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dc = pd.read_excel(r'C:\Users\mmoni\OneDrive\Documents\DAY_5_3.xlsx')
print(dc)
# Out:
#    company    job degree  salary
# 0           sales   bach       0
# 1        g  sales   mass       1
# 2        g    bus   bach       1
# 3        g    bus   mass       1
# 4        g   comp   bach       1
# 5      abc   comp   bach       0
# 6      abc  sales   mass       1
# 7      abc   comp   mass       0
# 8      abc  sales   bach       1
# 9       fb    bus   bach       1
# 10      fb    bus   bach       1
# 11      fb    bus   mass       1
# 12      fb   comp   bach       0
# 13      fb  sales   bach       0

# %%
x= dc.drop('salary', axis='columns')

y=dc['salary']

# %%
from sklearn.preprocessing import LabelEncoder
for_company= LabelEncoder()
for_job =LabelEncoder()
for_degree= LabelEncoder()

# %%
x['company_n']= for_company.fit_transform(x['company']) 

x['job_n']= for_job.fit_transform(x['job'])

x['degree_n']= for_degree.fit_transform(x['degree'])

x.head()
# Out:
#   company    job degree  company_n  job_n  degree_n
# 0          sales   bach          0      2         0
# 1       g  sales   mass          3      2         1
# 2       g    bus   bach          3      0         0
# 3       g    bus   mass          3      0         1
# 4       g   comp   bach          3      1         0

# %%
new=x.drop(['company','job','degree'],axis='columns')
print(new)
# Out:
#     company_n  job_n  degree_n
# 0           0      2         0
# 1           3      2         1
# 2           3      0         0
# 3           3      0         1
# 4           3      1         0
# 5           1      1         0
# 6           1      2         1
# 7           1      1         1
# 8           1      2         0
# 9           2      0         0
# 10          2      0         0
# 11          2      0         1
# 12          2      1         0
# 13          2      2         0

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier()

# %%
model.fit(new,y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(new,y)
model.predict([[2,0,1]])
# Out:
# C:\Users\mmoni\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
